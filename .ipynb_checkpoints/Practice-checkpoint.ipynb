# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('/Users/deepak/Desktop/NBA_Data/Every_Season_Data/[2005-2006]-combined-stats.csv')

# %% [markdown]
# Added another column that tessl the pts difference between both teams

# %%
df['pts_difference'] = df['away_score']-df['home_score']

# %% [markdown]
# #Remove Unnecessary features

# %%
df = df.drop(['a1', 'a2', 'a3','a4','a5','h1','h2','h3','h4','h5', 'play_length', 'entered', 'left', 'possession', 'shot_distance', 'original_x', 'original_y', 'converted_x', 'converted_y', 'num', 'away', 'home', 'outof', 'opponent', 'reason', 'elapsed', 'play_id'], axis = 1)

# %% [markdown]
# #set the parameters so I only see last two minutes of fourt quarter and OT

# %%
fouth_quarter = df[df['period']>=4]

# %%
clutch = fouth_quarter[(fouth_quarter['remaining_time'] < '00:02:00') | (fouth_quarter['period']>4)]

# %% [markdown]
# New Dataframe that only looks at the lcutch time that is with in 2 minutes and with in 5 points

# %%
clutch_time = clutch[clutch['pts_difference']>=-5]

# %%
clutch_time = clutch_time[clutch_time['pts_difference']<=5]

# %% [markdown]
# Remove all the rows that are not needed

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('sub')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('timeout')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('uknown')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('unknown')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('Ejection')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('violat')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('traveling')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('team reb')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('foul')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('turnover')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('of period')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('lost ball')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('goaltend')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('backcourt')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('bad pass')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('illegal')]

# %%
#clutch_time = clutch_time[~clutch_time.type.str.contains('Free Throw')]

# %%
clutch_time = clutch_time[~clutch_time.type.str.contains('jump ball')]

# %%
clutch_time = clutch_time[clutch_time.type != 'o']

# %% [markdown]
# Separate the playoff games from regular season games

# %%
regular_season = clutch_time[clutch_time['data_set']=='2005-2006 Regular Season']

# %%
playoffs= clutch_time[clutch_time['data_set']=='2006 Playoff']

# %%
playoffs['type'].unique()
# Out:
# array(['Free Throw 1 of 2', 'Free Throw 2 of 2', 'Jump Shot',
#        'rebound defensive', 'Turnaround Jump Shot', 'rebound offensive',
#        'Layup', 'Driving Layup', 'Dunk', 'Free Throw 1 of 1', 'Tip Shot',
#        'Follow Up Dunk', 'Running Jump Shot', 'Reverse Layup',
#        'Free Throw 1 of 3', 'Free Throw 2 of 3', 'Free Throw 3 of 3',
#        'Driving Dunk', 'Fadeaway Jumper', 'Jump Bank Shot', 'Finger Roll',
#        'Jump Hook Shot', 'Running Hook Shot', 'Slam Dunk',
#        'Free Throw Flagrant 2 of 2', 'Running Finger Roll',
#        'Driving Finger Roll', 'Driving Hook Shot', 'Alley Oop Layup',
#        'Hook Shot', 'Running Dunk'], dtype=object)

# %%
playoffs('type')[Free Throw 1 of 2] == 'Free Throw'
#df.xs('C')['x']=10
# Out:
#   File "<ipython-input-64-ede35fe0c487>", line 1
#     playoffs('type')[Free Throw 1 of 2] == 'Free Throw'
#                               ^
# SyntaxError: invalid syntax

# %%
p = playoffs[~playoffs.type.str.contains('Free Throw')]

# %%
p['event_type'].unique()
# Out:
# array(['miss', 'rebound', 'shot'], dtype=object)

# %%
pts = p[~p.event_type.str.contains('rebound')]

# %%
pts
# Out:
#               game_id      data_set        date  period  away_score  \
# 551716  ="0040500111"  2006 Playoff  2006-04-22       4         104
# 551718  ="0040500111"  2006 Playoff  2006-04-22       4         104
# 551720  ="0040500111"  2006 Playoff  2006-04-22       4         104
# 551722  ="0040500111"  2006 Playoff  2006-04-22       4         104
# 551727  ="0040500111"  2006 Playoff  2006-04-22       4         104
# 551743  ="0040500111"  2006 Playoff  2006-04-22       4         106
# 553041  ="0040500161"  2006 Playoff  2006-04-22       4          85
# 553043  ="0040500161"  2006 Playoff  2006-04-22       4          87
# 553050  ="0040500161"  2006 Playoff  2006-04-22       4          87
# 553061  ="0040500161"  2006 Playoff  2006-04-22       4          87
# 553064  ="0040500161"  2006 Playoff  2006-04-22       4          87
# 553922  ="0040500121"  2006 Playoff  2006-04-23       4          85
# 553929  ="0040500121"  2006 Playoff  2006-04-23       4          85
# ...

# %%
pts['player']
# Out:
# Jason Terry            23
# Kobe Bryant            18
# Tim Duncan             18
# Shawn Marion           17
# Gilbert Arenas         17
# Dwyane Wade            17
# Dirk Nowitzki          16
# Tim Thomas             16
# LeBron James           15
# Manu Ginobili          14
# Devin Harris           12
# Jerry Stackhouse       11
# Elton Brand            11
# Sam Cassell            10
# Boris Diaw             10
# Steve Nash              9
# Vince Carter            9
# Raja Bell               8
# Smush Parker            7
# Michael Finley          7
# Caron Butler            7
# Tony Parker             7
# Antawn Jamison          6
# Lamar Odom              5
# Jason Williams          5
# Anthony Johnson         5
# Shareef Abdur-Rahim     5
# Antoine Walker          4
# Jermaine O'Neal         4
# Nenad Krstic            4
# Udonis Haslem           4
# Mike Bibby              4
# Cuttino Mobley          4
# Carmelo Anthony         4
# Ronald Murray           4
# ...

# %%
#fourth_quarter = (regular_season[regular_season['period']>=4]) #| (regular_season_4th[regular_season_4th['remaining_time'] < '00:02:00'])

# %%
#fourth_quarter = fourth_quarter.drop(['a1', 'a2', 'a3','a4','a5','h1','h2','h3','h4','h5', 'play_length', 'entered', 'left', 'possession', 'shot_distance', 'original_x', 'original_y', 'converted_x', 'converted_y'], axis = 1)

# %%
#clutch_time = clutch_time.drop(['num', 'away', 'home', 'outof', 'opponent', 'reason', 'elapsed', 'play_id'], axis = 1)

# %%
#fourth_quarter['pts_difference'] = fourth_quarter['away_score']-fourth_quarter['home_score']

# %%
# fourth_quarter = fourth_quarter[fourth_quarter['pts_difference']>=-5]
# fourth_quarter = fourth_quarter[fourth_quarter['pts_difference']<=5]

# %%
#fourth_quarter['ot']=fourth_quarter['period']>=5

# %%
#clutch_time = fourth_quarter[(fourth_quarter['remaining_time'] < '00:02:00') | (fourth_quarter['period']>4)]
 #   regions = counties[(counties['REGION']==1]) | (counties['REGION']==2])]

# %%
#clutch_time = clutch_time.drop(['num', 'away', 'home', 'outof', 'opponent', 'reason', 'elapsed', 'play_id'], axis = 1)

# %%
x= clutch_time[~clutch_time.type.str.contains('foul')]
#df[~df.C.str.contains("XYZ")]


# x= regular_season_2min.ix[regular_season_2min['type']=='s.foul']
# x= regular_season_2min.ix[regular_season_2min['type']=='sub']
# x= regular_season_2min.ix[regular_season_2min['type']=='timeout: regular']

# %%
x= x[~x.type.str.contains('sub')]

# %%
x= x[~x.type.str.contains('timeout')]

# %%
x= x[~x.type.str.contains('unknown')]

# %%
#only looks at the shots
shots = x[x['type'].str.contains('hot')]

# %%
#dataframe with all the columns but with only when the shot was made
shots_made = shots[shots['event_type'].str.contains('hot')]
